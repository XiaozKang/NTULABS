# %% [markdown]
# # SC1015 Exercise 4

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Problem 1 (a)

# %%
train = pd.read_csv('train.csv')
saleprice = pd.DataFrame(train['SalePrice']) #Response
grlivarea = pd.DataFrame(train['GrLivArea']) #Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(grlivarea, saleprice, test_size = 0.2)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Saleprice values corresponding to grlivearea train data
y_train_pred = linreg.predict(X_train)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(X_train, y_train_pred, color = "r")
plt.show()
# Out:
# Intercept of Regression 	: b =  [18675.43572893]
# Coefficients of Regression 	: a =  [[107.42335337]]

# %% [markdown]
# # Problem 1(b)
# Goodness of Fit of the Model
#
# Check how good the predictions are on the Train Set.
#
# Metrics : Explained Variance and Mean Squared Error.

# %%
y_train_pred = linreg.predict(X_train)
# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

y_test_pred = linreg.predict(X_test)
# Check the Goodness of Fit (on Test Data)
print("Prediction Accuracy of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_test, y_test_pred)))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.504757507970594
# Mean Squared Error (MSE) 	: 3233566347.889503
# Root Mean Squared Error (RMSE) 	: 56864.455927138726
#
# Prediction Accuracy of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.48922121548843656
# Mean Squared Error (MSE) 	: 2766583976.64459
# Root Mean Squared Error (RMSE) 	: 52598.3267475743

# %% [markdown]
# # Problem 2

# %% [markdown]
# ### TotalBsmtSF

# %%
totalbsmtsf = pd.DataFrame(train['TotalBsmtSF']) #Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(totalbsmtsf, saleprice, test_size = 0.2)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Saleprice values corresponding to totalbsmtsf train data
y_train_pred = linreg.predict(X_train)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(X_train, y_train_pred, color = "r")
plt.show()

y_train_pred = linreg.predict(X_train)
# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

y_test_pred = linreg.predict(X_test)
# Check the Goodness of Fit (on Test Data)
print("Prediction Accuracy of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_test, y_test_pred)))
print()
# Out:
# Intercept of Regression 	: b =  [65373.26494981]
# Coefficients of Regression 	: a =  [[109.4075403]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.37606156553069114
# Mean Squared Error (MSE) 	: 3962606914.037612
# Root Mean Squared Error (RMSE) 	: 62949.24077411587
#
# Prediction Accuracy of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.37753037757084906
# Mean Squared Error (MSE) 	: 3814469883.982606
# Root Mean Squared Error (RMSE) 	: 61761.39477037906

# %% [markdown]
# ### GarageArea

# %%
garagearea = pd.DataFrame(train['GarageArea']) #Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(garagearea, saleprice, test_size = 0.2)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Saleprice values corresponding to garagearea train data
y_train_pred = linreg.predict(X_train)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(X_train, y_train_pred, color = "r")
plt.show()

y_train_pred = linreg.predict(X_train)
# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()

y_test_pred = linreg.predict(X_test)
# Check the Goodness of Fit (on Test Data)
print("Prediction Accuracy of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_test, y_test_pred)))
print()
# Out:
# Intercept of Regression 	: b =  [69554.40221778]
# Coefficients of Regression 	: a =  [[235.99519746]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.3885743305229351
# Mean Squared Error (MSE) 	: 4072975989.428711
# Root Mean Squared Error (RMSE) 	: 63819.87143068146
#
# Prediction Accuracy of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.3870435314229478
# Mean Squared Error (MSE) 	: 2990487964.150587
# Root Mean Squared Error (RMSE) 	: 54685.354201564674

# %% [raw]
# ## Conclusion with results obtained for each case with random data chosen
# GrLivArea
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.504757507970594
# Mean Squared Error (MSE) 	: 3233566347.889503
# Root Mean Squared Error (RMSE) 	: 56864.455927138726
# Prediction Accuracy of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.48922121548843656
# Mean Squared Error (MSE) 	: 2766583976.64459
# Root Mean Squared Error (RMSE) 	: 52598.3267475743
#
# TotalBsmtSF
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.37606156553069114
# Mean Squared Error (MSE) 	: 3962606914.037612
# Root Mean Squared Error (RMSE) 	: 62949.24077411587
# Prediction Accuracy of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.37753037757084906
# Mean Squared Error (MSE) 	: 3814469883.982606
# Root Mean Squared Error (RMSE) 	: 61761.39477037906
#
# GarageArea
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.3885743305229351
# Mean Squared Error (MSE) 	: 4072975989.428711
# Root Mean Squared Error (RMSE) 	: 63819.87143068146
# Prediction Accuracy of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.3870435314229478
# Mean Squared Error (MSE) 	: 2990487964.150587
# Root Mean Squared Error (RMSE) 	: 54685.354201564674

# %% [markdown]
# From the results above, since the GrLivArea has the largest explained variance on both train and test data sets as compared to other variables, it suggest its model has the greatest proportion that can account for the variance in data sets. Thus, GrLivArea model is the best in this case.

# %% [markdown]
# # Problem 3(a)

# %%
#Creating a new data frame for only grlivearea and saleprice only
jointDF = pd.DataFrame(train[['GrLivArea', 'SalePrice']])

#Identifying out the outliers
Q1 = jointDF.quantile (0.25)
Q2 = jointDF.quantile (0.75)
IQR = Q2 - Q1

jointDF.info()
((jointDF < (Q1 - 1.5 * IQR)) | (jointDF > (Q2 + 1.5 * IQR))).sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GrLivArea  1460 non-null   int64
#  1   SalePrice  1460 non-null   int64
# dtypes: int64(2)
# memory usage: 22.9 KB
# GrLivArea    31
# SalePrice    61
# dtype: int64

# %%
#Removing the outliers
jointDF_clean = jointDF[~((jointDF < (Q1 - 1.5 * IQR)) |(jointDF > (Q2 + 1.5 * IQR))).any(axis=1)]

#Checking if the outliers have been successfully removed
jointDF_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1383 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GrLivArea  1383 non-null   int64
#  1   SalePrice  1383 non-null   int64
# dtypes: int64(2)
# memory usage: 32.4 KB

# %% [markdown]
# The outliers have been successfully removed.

# %% [markdown]
# # Problem 3(b)

# %%
saleprice = pd.DataFrame(jointDF_clean['SalePrice']) #Response
grlivarea = pd.DataFrame(jointDF_clean['GrLivArea']) #Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(grlivarea, saleprice, test_size = 0.2)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Saleprice values corresponding to grlivearea train data
y_train_pred = linreg.predict(X_train)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(X_train, y_train_pred, color = "r")
plt.show()
# Out:
# Intercept of Regression 	: b =  [34330.86021539]
# Coefficients of Regression 	: a =  [[92.39684625]]

# %% [markdown]
# # Problem 3(c)

# %%
##Using jointDF_clean data set
y_train_pred = linreg.predict(X_train)
# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print()
y_test_pred = linreg.predict(X_test)
# Check the Goodness of Fit (on Test Data)
print("Prediction Accuracy of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(y_test, y_test_pred)))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.48167788550231727
# Mean Squared Error (MSE) 	: 1782254592.8201559
# Root Mean Squared Error (RMSE) 	: 42216.7572513588
#
# Prediction Accuracy of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.4587356325854456
# Mean Squared Error (MSE) 	: 1871218581.103133
# Root Mean Squared Error (RMSE) 	: 43257.58408768493

# %% [markdown]
# This model is definitely better than the model obtained in Problem 1 for the same variables. This is because after the outliers have been removed, both MSE and RMSE for jointDF_clean data set had dropped significantly which is great since an ideal model seeks for minimal error.
